# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/female1.jpg')
img.shape
# Out:
# (545, 765, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (545, 765)

# %%
gray
# Out:
# array([[254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        ...,
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254],
#        [254, 254, 254, ..., 254, 254, 254]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[313, 106, 122, 122]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (313, 106, 122, 122)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (122, 122, 3)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/female1.jpg')
plt.imshow(cropped_image)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test_images/male2.jpg')
cropped_image_no_2_eyes

# %%
path_to_data = "./data/"
path_to_cr_data = "./data/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./data/cropped', './data/Female', './data/Male']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./data/cropped/Female
# Generating cropped images in folder:  ./data/cropped/Male

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Female': ['./data/cropped/Female\\Female1.png',
#   './data/cropped/Female\\Female10.png',
#   './data/cropped/Female\\Female11.png',
#   './data/cropped/Female\\Female12.png',
#   './data/cropped/Female\\Female13.png',
#   './data/cropped/Female\\Female14.png',
#   './data/cropped/Female\\Female15.png',
#   './data/cropped/Female\\Female16.png',
#   './data/cropped/Female\\Female17.png',
#   './data/cropped/Female\\Female19.png',
#   './data/cropped/Female\\Female2.png',
#   './data/cropped/Female\\Female20.png',
#   './data/cropped/Female\\Female21.png',
#   './data/cropped/Female\\Female22.png',
#   './data/cropped/Female\\Female23.png',
#   './data/cropped/Female\\Female24.png',
#   './data/cropped/Female\\Female25.png',
#   './data/cropped/Female\\Female26.png',
#   './data/cropped/Female\\Female27.png',
#   './data/cropped/Female\\Female28.png',
#   './data/cropped/Female\\Female29.png',
#   './data/cropped/Female\\Female3.png',
#   './data/cropped/Female\\Female30.png',
#   './data/cropped/Female\\Female31.png',
#   './data/cropped/Female\\Female32.png',
#   './data/cropped/Female\\Female33.png',
#   './data/cropped/Female\\Female34.png',
#   './data/cropped/Female\\Female35.png',
#   './data/cropped/Female\\Female36.png',
#   './data/cropped/Female\\Female37.png',
#   './data/cropped/Female\\Female38.png',
#   './data/cropped/Female\\Female39.png',
#   './data/cropped/Female\\Female4.png',
#   './data/cropped/Female\\Female40.png',
#   './data/cropped/Female\\Female41.png',
#   './data/cropped/Female\\Female42.png',
#   './data/cropped/Female\\Female43.png',
#   './data/cropped/Female\\Female44.png',
#   './data/cropped/Female\\Female45.png',
#   './data/cropped/Female\\Female47.png',
#   './data/cropped/Female\\Female48.png',
#   './data/cropped/Female\\Female49.png',
#   './data/cropped/Female\\Female5.png',
#   './data/cropped/Female\\Female50.png',
#   './data/cropped/Female\\Female51.png',
#   './data/cropped/Female\\Female52.png',
#   './data/cropped/Female\\Female53.png',
#   './data/cropped/Female\\Female54.png',
#   './data/cropped/Female\\Female55.png',
#   './data/cropped/Female\\Female56.png',
#   './data/cropped/Female\\Female7.png',
#   './data/cropped/Female\\Female8.png',
#   './data/cropped/Female\\Female9.png'],
#  'Male': ['./data/cropped/Male\\Male1.png',
#   './data/cropped/Male\\Male10.png',
#   './data/cropped/Male\\Male11.png',
#   './data/cropped/Male\\Male12.png',
#   './data/cropped/Male\\Male13.png',
#   './data/cropped/Male\\Male14.png',
#   './data/cropped/Male\\Male15.png',
#   './data/cropped/Male\\Male16.png',
#   './data/cropped/Male\\Male17.png',
#   './data/cropped/Male\\Male18.png',
#   './data/cropped/Male\\Male19.png',
#   './data/cropped/Male\\Male2.png',
#   './data/cropped/Male\\Male20.png',
#   './data/cropped/Male\\Male21.png',
#   './data/cropped/Male\\Male22.png',
#   './data/cropped/Male\\Male23.png',
#   './data/cropped/Male\\Male24.png',
#   './data/cropped/Male\\Male25.png',
#   './data/cropped/Male\\Male26.png',
#   './data/cropped/Male\\Male27.png',
#   './data/cropped/Male\\Male28.png',
#   './data/cropped/Male\\Male29.png',
#   './data/cropped/Male\\Male3.png',
#   './data/cropped/Male\\Male30.png',
#   './data/cropped/Male\\Male31.png',
#   './data/cropped/Male\\Male32.png',
#   './data/cropped/Male\\Male33.png',
#   './data/cropped/Male\\Male34.png',
#   './data/cropped/Male\\Male35.png',
#   './data/cropped/Male\\Male36.png',
#   './data/cropped/Male\\Male37.png',
#   './data/cropped/Male\\Male38.png',
#   './data/cropped/Male\\Male4.png',
#   './data/cropped/Male\\Male40.png',
#   './data/cropped/Male\\Male41.png',
#   './data/cropped/Male\\Male42.png',
#   './data/cropped/Male\\Male43.png',
#   './data/cropped/Male\\Male44.png',
#   './data/cropped/Male\\Male5.png',
#   './data/cropped/Male\\Male6.png',
#   './data/cropped/Male\\Male7.png',
#   './data/cropped/Male\\Male8.png',
#   './data/cropped/Male\\Male9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Female': 0, 'Male': 1}

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X[0]
# Out:
# array([[ 62],
#        [110],
#        [122],
#        ...,
#        [ 33],
#        [ 19],
#        [251]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (96, 4096)

# %%
len(X)
# Out:
# 96

# %%
X[0]
# Out:
# array([ 62., 110., 122., ...,  33.,  19., 251.])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'linear', C = 1))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.875

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89        12
#            1       1.00      0.75      0.86        12
#
#     accuracy                           0.88        24
#    macro avg       0.90      0.88      0.87        24
# weighted avg       0.90      0.88      0.87        24

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.931429
# 1        random_forest    0.816190
# 2  logistic_regression    0.916190
#
#                                    best_params
# 0       {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 5}
# 2                 {'logisticregression__C': 5}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=5))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=5, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.875

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.9166666666666666

# %%
best_clf = best_estimators['logistic_regression']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[11,  1],
#        [ 1, 11]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\91920\anaconda3\lib\site-packages (1.1.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
